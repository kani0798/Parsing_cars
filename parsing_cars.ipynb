# %% [markdown]
# # Import libraries

# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
URL = "https://cars.kg/offers/?vendor=57fa24ee2860c45a2a2c08b0"

# %%
r = requests.get(URL)

# %%
html = r.text

# %%
html
# Out:
# '<!DOCTYPE html>\n<html lang="ru-ru">\n<head>\n    \n<meta http-equiv="content-type" content="text/html; charset=utf-8">\n    <meta name="viewport" content="width=1024,user-scalable=yes">\n<meta property="og:site_name" content="Cars.kg - Все автомобили Кыргызстана. Продажа и покупка автомобилей и запчастей. Бишкек и весь Кыргызстан"/>\n\n            <title>Легковые автомобили BMW  - cars.kg Все автомобили Кыргызстана. Продажа и покупка автомобилей и запчастей. Бишкек и весь Кыргызстан</title>\n                <meta name="description" content="Купить BMW , объявления и цены на авто BMW  в Бишкеке и Кыргызстане" />\n                            <meta property="og:title" content="cars.kg Все автомобили Кыргызстана. Продажа и покупка автомобилей и запчастей. Бишкек и весь Кыргызстан" />\n                                        <meta property="fb:admins" content="100001075845884" />\n<meta property="og:description" content="cars.kg Все автомобили Кыргызстана. Продажа и покупка автомобилей и запчастей. Бишкек и весь Кыргызстан">\n    <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.cars.kg/offers">\n    <link href="//fonts.googleapis.com/css?family=Roboto:400,500,700&subset=cyrillic" rel="stylesheet">\n    <!--  -->\n    <link rel="stylesheet" href="/build/vendor/swiper/swiper.min.css" type="text/css">\n    <link rel="stylesheet" href="/build/vendor/fotorama/fotorama.css" type="text/css">\n    <link rel="stylesheet" href="/build/css/styles.desk.css" type="text/css">\n    <link rel="stylesheet" href="/build/css/intlTelInput.css">\n    <!--  -->\n    <script src="//ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js"></script>\n    <script src="/build/vendor/fotorama/fotorama.js"></script>\n    <script src="//cdnjs.cloudflare.com/ajax/libs/Swiper/3.3.1/js/swiper.min.js"></script>\n    <script src="/build/js/intlTelInput.js"></script>\n    <script src="/build/js/js.js"></script>\n    <script type="text/javascript" src="https://vk.com/js/api/share.js?94" charset="windows-1251"></script>\n    <meta name="yandex-verification" content="9279102db0134beb"/>\n    <meta name="google-play-app" content="app-id=app.cars.kg.carsapplication">\n        <script src=\'//www.google.com/recaptcha/api.js\'></script>\n</head>\n<body ontouchstart="">\n<svg style="width:0;height:0;display: none"><symbol viewBox="0 0 8 14" id="i-arr-left"><path d="M.32 6.999a.931.931 0 0 0 .274.666l5.74 5.74A.937.937 0 1 0 7.66 12.08L2.58 7.001l5.08-5.08A.937.937 0 1 0 6.335.594l-5.74 5.74a.994.994 0 0 0-.002.003A.932.932 0 0 0 .317 7z" fill-rule="evenodd"/></symbol><symbol viewBox="0 0 8 14" id="i-arr-right"><path d="M7.68 6.999a.931.931 0 0 1-.274.666l-5.74 5.74A.937.937 0 1 1 .34 12.08l5.08-5.079L.34 1.92A.937.937 0 1 1 1.665.594l5.74 5.74a.994.994 0 0 1 .002.003.932.932 0 0 1 .275.663z" fill-rule="evenodd"/></symbol><symbol viewBox="0 0 17 14" id="i-auto"><path d="M14.82 4.677l-1.335-3.45c-.25-.66-.796-1.222-1.83-1.227H4.634c-1.03.005-1.575.567-1.83 1.227l-1.336 3.45C.938 4.746-.002 5.37 0 6.55v4.393h1.304v1.403c-.003 1.729 2.443 1.708 2.442 0v-1.403h8.797v1.403c.005 1.708 2.451 1.729 2.453 0v-1.403H16.3V6.55c-.004-1.18-.944-1.804-1.48-1.873zM2.565 8.292c-.625.002-1.131-.519-1.129-1.16-.002-.646.504-1.167 1.129-1.162.622-.005 1.128.516 1.128 1.162 0 .641-.506 1.162-1.128 1.16zM8.15 4.645H2.86l1.007-2.717c.121-.386.31-.661.756-.668h7.054c.44.007.629.282.756.668l1.008 2.717H8.15zm5.587 3.647c-.63.002-1.136-.519-1.14-1.16.004-.646.51-1.167 1.14-1.162.618-.005 1.124.516 1.128 1.162-.004.641-.51 1.162-1.128 1.16z" fill-rule="evenodd"/></symbol><symbol viewBox="0 0 53 21" id="i-car"><path d="M46.834 16.118c-.167 0-.3.003-.412.012-.053 0-.118-.002-.176-.004.002-.057.008-.112.007-.17-.023-2.734-2.256-4.958-5.02-4.958-2.744.024-4.958 2.286-4.936 5.044 0 .026.004.05.005.077-.08 0-.164.002-.236.003-.495.01-1.022.04-1.546.072-.56.033-1.14.066-1.655.07l-10.958.095c-.26.003-.528.004-.8.004-1.5 0-2.68-.044-3.592-.135-.09-.01-.194-.02-.304-.03.005-.08 ...

# %%
soup = BeautifulSoup(html, "lxml")

# %%
soup.find("span", class_="catalog-item-caption").text.strip()
# Out:
# 'BMW 5 серия E34 Седан , 1992'

# %%
soup.find("span", class_="catalog-item-price").text.strip()
# Out:
# '3900$'

# %%
soup.find("img", class_="catalog-item-cover-img").get("src")
# Out:
# 'https://i.cars.kg/preview/r/J6IPxNYV91vc6LXyQAevCw/1080x-/20230227/63a5c03b3138f0e2c88987234fbbf20b.jpg'

# %%
for tag in soup.find_all("span", class_="catalog-item-caption"):
  print(tag.text)
# Out:
#             BMW 5 серия E34 Седан , 1992
#
#             BMW 5 серия E60/E61 [рестайлинг] Седан , 2007
#
#             BMW X5 E70 Кроссовер , 2007
#
#             BMW X6 F16 Sports Activity Coupe кроссовер , 2016
#
#             BMW X5 E53 [рестайлинг] Кроссовер , 2005
#
#             BMW X5 E70 [рестайлинг] Кроссовер , 2012
#
#             BMW 5 серия E39 [рестайлинг] Touring универсал , 2003
#
#             BMW 5 серия E60/E61 Седан , 2003
#
#             BMW 5 серия E60/E61 , 2003
#
#             BMW 5 серия E39 [рестайлинг] Седан , 2001
#
#             BMW 5 серия F07/F10/F11 [рестайлинг] Седан , 2017
#
#             BMW X5 F15 Кроссовер , 2016
#
#             BMW Х7, 2020
#
#             BMW 3 серия E46 Седан 4-дв. , 1998
#
#             BMW X5 E53 Кроссовер , 2003
#
#             BMW Х7, 2019
#
#             BMW X5 E53 Кроссовер , 2001
#
#             BMW X5 F15 Кроссовер , 2020
#
#             BMW X5 E70 Кроссовер , 2008
#
#             BMW 5 серия E39 [рестайлинг] Седан , 2002

# %%
for image in soup.find_all("img", class_="catalog-item-cover-img"):
  print(image.get("src"))
# Out:
# https://i.cars.kg/preview/r/J6IPxNYV91vc6LXyQAevCw/1080x-/20230227/63a5c03b3138f0e2c88987234fbbf20b.jpg
# https://i.cars.kg/preview/r/RlzEY-XjcLCIVYa-XfeOLA/1080x-/20230226/a29ddeaaa43d2b8670b531c61c6fd478.jpg
# https://i.cars.kg/preview/r/S5P-v2oCLBiuS6V9lYtPkA/1080x-/20230226/1211d267e71b1f35b120d6aa2afdda17.webp
# https://i.cars.kg/preview/r/7nFVtFGIDuMu0wfoNGdRuQ/1080x-/20230224/425555c070011dcafdc01d08576b6e1f.jpg
# https://i.cars.kg/preview/r/LOP0Nqarq0oK-fQW35XWKQ/1080x-/20230223/b37ed1dd725767c5d3a2bfc7d06b5ce0.jpg
# https://i.cars.kg/preview/r/OQEO19-Kjjavo-VPSPpvZg/1080x-/20230221/d1c8d6500c885fe31c9ed7ae7ee9b191.jpg
# https://i.cars.kg/preview/r/pqHA7KA5a9FjU2WsqxJ6Lw/1080x-/20230221/813c00ace14baacebe8acf27a8918d1d.jpg
# https://i.cars.kg/preview/r/7Ihvlqc-HzSLjxRZe46oWQ/1080x-/20230219/222535d688571a34aa4adf9230db717d.jpg
# https://i.cars.kg/preview/r/ozbzfSmvprYCDNenjeW4xQ/1080x-/20230218/e926eb7f853982b444c745312a56769d.jpg
# https://i.cars.kg/preview/r/ef0SA6wqxTbGYOOQCC20hA/1080x-/20230217/416c41db88c7341ddfe172952fd229cd.jpg
# https://i.cars.kg/preview/r/WV3ODCs__Pz5BlJZfO4m0A/1080x-/20230216/81fcd0cf9e5ad6d457f727555b7c7e3b.jpg
# https://i.cars.kg/preview/r/LPiWC0SBR7vhbDYlDKz69A/1080x-/20230216/13a6aa8bfcf1001a314f5e8f952a8192.jpg
# https://i.cars.kg/preview/r/Lpu_fCvhD4Onkpt_d4lvpA/1080x-/20230214/e6fbbc8ab838eb503cc9d8b562008095.jpg
# https://i.cars.kg/preview/r/jCXFbuRVmPm7dGp9AXAsLw/1080x-/20230213/06c087753268636750786a5b938cd919.jpg
# https://i.cars.kg/preview/r/1DXlKifMUaWrVd50QlNCbQ/1080x-/20230212/b41613e7ce3a32cb457374bd698cec04.jpg
# https://i.cars.kg/preview/r/c8kPX_dqVTK6FD7TTdLX4A/1080x-/20230212/0432ce2a20bdaeec8067318c713fd517.jpg
# https://i.cars.kg/preview/r/WwmNche91z6NwTDvRc0llw/1080x-/20230211/24ba80f0ff06032d1bc04201a4925a90.jpg
# https://i.cars.kg/preview/r/HpMtjyNie22ruXoaFjTNVg/1080x-/20230211/9a6654908ac8d2d86bfbd00701a52d2a.jpg
# https://i.cars.kg/preview/r/3DPXJIVujtJlVsSmMPgDCw/1080x-/20230210/a59eb879db83bd3a885e6cb5359651c0.jpg
# https://i.cars.kg/preview/r/ZwaMqYdo09j_DbV_wt3o9g/1080x-/20230208/63bd646397af909d55ca6decec5e0c80.jpg

# %% [markdown]
# # Parsing

# %%
def get_response(url: str) -> str:
  response = requests.get(url)
  return response.text

# %%
def write_headers() -> None:
    with open('cars.csv', 'w', newline='') as csvfile:
        fieldnames = ['title', 'price', 'image']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

def write_to_csv(data: dict) -> None:
    with open('cars.csv', 'a', newline='') as csvfile:
      fieldnames = ['title', 'price', 'image']
      writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      writer.writerow(data)

# %%
def get_data(html: str) -> None:
  soup = BeautifulSoup(html, "lxml")
  catalog = soup.find("div", class_="main catalog")
  a_tags = catalog.find_all("a", class_="catalog-list-item")
  for a_tag in a_tags:
    try:
      title = a_tag.find("span", class_="catalog-item-caption").text.strip()
    except AttributeError:
      title = "No title"
    try :
      image = a_tag.find("img", class_="catalog-item-cover-img").get("src")
    except AttributeError:
      image = "https://www.seat.com.mt/content/dam/public/seat-website/carworlds/compare/default-image/ghost.png"
    try:
      price = a_tag.find("span", class_="catalog-item-price").text.strip()
    except AttributeError:
      price = "Договорная"
    
    data = {
        "title": title,
        "price": price,
        "image": image
    }
    write_to_csv(data)

# %%
def get_last_page(html: str) -> int:
  soup = BeautifulSoup(html, "lxml")
  pages = soup.find_all('a', class_="pages-item")
  last_page = pages[-2].text
  return int(last_page)

# %%
def main(URL: str) -> None:
  write_headers()
  html = get_response(URL)
  last_page = get_last_page(html)
  for page in range(1, last_page+1):
    url = f"https://cars.kg/offers/{page}?vendor=57fa24ee2860c45a2a2c08b0"
    current_page_html = get_response(url)
    get_data(current_page_html)

# %%
URL = "https://cars.kg/offers/?vendor=57fa24ee2860c45a2a2c08b0"
main(URL)
